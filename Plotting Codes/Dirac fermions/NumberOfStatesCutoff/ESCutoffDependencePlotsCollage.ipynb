# %%
import numpy as np
import mpmath as mp
import matplotlib.pyplot as plt

# %%
MM1, E1 = np.loadtxt("ES_DF_m_2_cutoff_1.dat",usecols=(0,1),unpack=True)
MM2, E2 = np.loadtxt("ES_DF_m_2_cutoff_2.dat",usecols=(0,1),unpack=True)
MM3, E3 = np.loadtxt("ES_DF_m_2_cutoff_6.dat",usecols=(0,1),unpack=True)
MM4, E4 = np.loadtxt("ES_DF_m_2_cutoff_10.dat",usecols=(0,1),unpack=True)
MM5, E5 = np.loadtxt("ES_DF_m_2_cutoff_15.dat",usecols=(0,1),unpack=True)
MM6, E6 = np.loadtxt("ES_DF_m_2_cutoff_30.dat",usecols=(0,1),unpack=True)

# %%
SMALL_SIZE = 30
MEDIUM_SIZE = 30
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.rc('axes', axisbelow=True)

fig,[[ax1,ax2],[ax3,ax4],[ax5,ax6]] = plt.subplots(3,2,sharex=True,sharey=True,figsize=(16,12),constrained_layout=True)
fig.set_constrained_layout_pads(w_pad=4 / 72, h_pad=1 / 72, hspace=0.0, wspace=0.0)
ax = fig.gca()
# Major ticks every 20, minor ticks every 5
xmajor_ticks = np.arange(-5, 10, 5)
xminor_ticks = np.arange(-5, 10, 2.5)
ymajor_ticks = np.arange(0, 1.5, 0.5)
yminor_ticks = np.arange(0, 1.5, 0.25)

ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)

left  = 0.125  # the left side of the subplots of the figure
right = 0.9    # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.2   # the amount of height reserved for white space between subplots

# plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)

'''Plot 1'''
ax1.grid(which='both')
ax1.yaxis.set_tick_params(width=2, length=5)
ax1.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax1.scatter(MM1,E1,s=24,color="#2E4272")
# ax1.set_xlabel("$\ell$",color="#061539")
ax1.set_ylabel("$\lambda$",color="#061539")
ax1.text(-5,1.2,"(a)",fontsize=30,fontweight="bold",va="top",ha="right")
ax1.text(2.8, 0.9, "$\Lambda = 1$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))

'''Plot 2'''
ax2.grid(which='both')
ax2.yaxis.set_tick_params(width=2, length=5)
ax2.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax2.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax2.scatter(MM2,E2,s=24,color="#2E4272")
# ax2.set_xlabel("$\ell$",color="#061539")
# ax2.set_ylabel("$\lambda$",color="#061539")
ax2.text(-5,1.2,"(b)",fontsize=30,fontweight="bold",va="top",ha="right")
ax2.text(2.8, 0.9, "$\Lambda = 2$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))

'''Plot 3'''
ax3.grid(which='both')
ax3.yaxis.set_tick_params(width=2, length=5)
ax3.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax3.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax3.scatter(MM3,E3,s=24,color="#2E4272")
# ax3.set_xlabel("$\ell$",color="#061539")
ax3.set_ylabel("$\lambda$",color="#061539")
ax3.text(-5,1.2,"(c)",fontsize=30,fontweight="bold",va="top",ha="right")
ax3.text(2.8, 0.9, "$\Lambda = 6$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))

'''Plot 4'''
ax4.grid(which='both')
ax4.yaxis.set_tick_params(width=2, length=5)
ax4.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax4.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax4.scatter(MM4,E4,s=24,color="#2E4272")
# ax4.set_xlabel("$\ell$",color="#061539")
# ax4.set_ylabel("$\lambda$",color="#061539")
ax4.text(-5,1.2,"(d)",fontsize=30,fontweight="bold",va="top",ha="right")
ax4.text(2.8, 0.9, "$\Lambda = 10$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))


'''Plot 5'''
ax5.grid(which='both')
ax5.yaxis.set_tick_params(width=2, length=5)
ax5.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax5.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax5.scatter(MM5,E5,s=24,color="#2E4272")
ax5.set_xlabel("$\ell$",color="#061539")
ax5.set_ylabel("$\lambda$",color="#061539")
ax5.text(-5,1.2,"(e)",fontsize=30,fontweight="bold",va="top",ha="right")
ax5.text(2.8, 0.9, "$\Lambda = 15$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))

'''Plot 6'''
ax6.grid(which='both')
ax6.yaxis.set_tick_params(width=2, length=5)
ax6.xaxis.set_tick_params(width=2, length=5)
for axes in ['top', 'bottom', 'left', 'right']:
    ax6.spines[axes].set_linewidth(0.5)

# left, bottom, width, height = [0.2, 0.76, 0.6, 0.6]
# ax2 = fig.add_axes([left, bottom, width, height])
# ax2.imshow(im)
# ax2.axis("off")
# ax2.scatter(MM,EE,s=1,color="green")
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_xlabel("$m$")
# ax2.set_ylabel("$E$")

ax6.scatter(MM6,E6,s=24,color="#2E4272")
ax6.set_xlabel("$\ell$",color="#061539")
# ax6.set_ylabel("$\lambda$",color="#061539")
ax6.text(-5,1.2,"(f)",fontsize=30,fontweight="bold",va="top",ha="right")
ax6.text(2.8, 0.9, "$\Lambda = 30$", fontsize=30,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='grey', alpha=0.8))

# plt.xlabel("m",color="#061539")
plt.xlim(-5,5)
plt.savefig("DFESCutoffDependence.pdf",bbox_inches="tight",pad_inches=0.4,dpi=300)
plt.show()
